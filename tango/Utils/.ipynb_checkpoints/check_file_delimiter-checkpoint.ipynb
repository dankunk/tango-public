# %% [markdown]
# # Check Delimiter
# ### This is a simple script to check the delimiter of a file using the csv library in python

# %%
# import the csv library
import csv

# set the file name variable to the file name of your choice
file_name = "C:\\path\\to\\file.txt"

# conditional that will open the file in question as f
with open(metadata, newline='') as f:
    sample = f.read(1024)                # read a bit of the file with read, number is number of bytes to read aka characters
    dialect = csv.Sniffer().sniff(sample) # use csv sniffer function to sniff the sample text
    print("Delimiter is:", repr(dialect.delimiter)) # print to the user what the delimiter is given the above line resutls.
